# %%
import datetime
datetime.datetime.strptime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# %%
headers = ['Name', 'x', 'y']
table3 = [['Kasios Office Furniture', 90, 21], ['Radiance ColourTek', 109, 26], ['Indigo Sol Boards', 120, 22], 
          ['Roadrunner Fitness Electronics', 89, 27], ['Sensor 1', 62, 21], ['Sensor 2', 66, 35], ['Sensor 3', 76, 41], 
          ['Sensor 4', 88, 45], ['Sensor 5', 103, 43], ['Sensor 6', 102, 22], ['Sensor 7', 89, 3], ['Sensor 8', 74, 7], 
          ['Sensor 9', 119, 42]]

new_df = pd.DataFrame(table3)
new_df.columns = headers
new_df
# Out:
#                               Name    x   y
# 0          Kasios Office Furniture   90  21
# 1               Radiance ColourTek  109  26
# 2                Indigo Sol Boards  120  22
# 3   Roadrunner Fitness Electronics   89  27
# 4                         Sensor 1   62  21
# 5                         Sensor 2   66  35
# 6                         Sensor 3   76  41
# 7                         Sensor 4   88  45
# 8                         Sensor 5  103  43
# 9                         Sensor 6  102  22
# 10                        Sensor 7   89   3
# 11                        Sensor 8   74   7
# 12                        Sensor 9  119  42

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=new_df,x='x',y='y')
plt.title('Locations') #title
plt.xlabel('x') #x label
plt.ylabel('y') #y label
plt.text(new_df.x[new_df.Name =='Kasios Office Furniture']- 2.5, new_df.y[new_df.Name == 'Kasios Office Furniture'] - 2.5,
         "Kasios", color='black')
plt.text(new_df.x[new_df.Name == 'Radiance ColourTek']+ 1,new_df.y[new_df.Name == 'Radiance ColourTek']+ 1,
         "Radiance", color='black')
plt.text(new_df.x[new_df.Name == 'Indigo Sol Boards'] - 2.5,new_df.y[new_df.Name == 'Indigo Sol Boards'] - 2.5,
         "Indigo", color='black')
plt.text(new_df.x[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,new_df.y[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,
         "Roadrunner", color='black')
plt.text(new_df.x[new_df.Name == 'Sensor 1']- 2.5, new_df.y[new_df.Name == 'Sensor 1']- 2.5, "Sensor 1", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 2']- 2.5, new_df.y[new_df.Name == 'Sensor 2']- 2.5, "Sensor 2", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 3']- 2.5, new_df.y[new_df.Name == 'Sensor 3']- 2.5, "Sensor 3", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 4']- 2.5, new_df.y[new_df.Name == 'Sensor 4']- 2.5, "Sensor 4", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 5']- 2.5, new_df.y[new_df.Name == 'Sensor 5']- 2.5, "Sensor 5", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 6']- 2.5, new_df.y[new_df.Name == 'Sensor 6']- 2.5, "Sensor 6", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 7']- 2.5, new_df.y[new_df.Name == 'Sensor 7']- 2.5, "Sensor 7", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 8']- 2.5, new_df.y[new_df.Name == 'Sensor 8']- 2.5, "Sensor 8", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 9']- 2.5, new_df.y[new_df.Name == 'Sensor 9']- 2.5, "Sensor 9", color='red')

plt.xlim(new_df.x.min()-5,new_df.x.max()+5)
plt.ylim(new_df.y.min()-5,new_df.y.max()+5)
plt.show()
