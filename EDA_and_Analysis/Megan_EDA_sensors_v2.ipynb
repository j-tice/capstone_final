# %%
import datetime
datetime.datetime.strptime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# %%
sensor_data = pd.read_excel('Sensor Data.xlsx')
sensor_data
# Out:
#              Chemical  Monitor          Date Time    Reading
# 0      Methylosmolene        3 2016-04-01 00:00:00  2.683820
# 1      Methylosmolene        7 2016-04-01 00:00:00  2.630640
# 2        Chlorodinine        3 2016-04-01 00:00:00  1.259170
# 3        Chlorodinine        7 2016-04-01 00:00:00  0.943983
# 4             AGOC-3A        3 2016-04-01 00:00:00  0.722303
# ...               ...      ...                 ...       ...
# 79238         AGOC-3A        1 2016-12-31 23:00:00  0.078266
# 79239  Methylosmolene        3 2016-12-31 23:00:00  0.062784
# 79240         AGOC-3A        2 2016-12-31 23:00:00  0.060814
# 79241     Appluimonia        7 2016-12-31 23:00:00  0.039729
# 79242         AGOC-3A        7 2016-12-31 23:00:00  0.014658
#
# [79243 rows x 4 columns]

# %%
sensor_data.columns
# Out:
# Index(['Chemical', 'Monitor', 'Date Time ', 'Reading'], dtype='object')

# %%
sensor_data.rename({'Date Time ': 'Date_Time'}, axis=1, inplace=True)
sensor_data.columns
# Out:
# Index(['Chemical', 'Monitor', 'Date_Time', 'Reading'], dtype='object')

# %%
sensor_data.isna().sum()
# Out:
# Chemical     0
# Monitor      0
# Date_Time    0
# Reading      0
# dtype: int64

# %%
# Convert Date_Time column to datetime

pd.to_datetime(sensor_data['Date_Time'])
sensor_data.dtypes
# Out:
# Chemical             object
# Monitor               int64
# Date_Time    datetime64[ns]
# Reading             float64
# dtype: object

# %%
# Now that the Date_Time column is a datetime, we can make it the index
sensor_data.set_index('Date_Time')
# Out:
#                            Chemical  Monitor   Reading
# Date_Time
# 2016-04-01 00:00:00  Methylosmolene        3  2.683820
# 2016-04-01 00:00:00  Methylosmolene        7  2.630640
# 2016-04-01 00:00:00    Chlorodinine        3  1.259170
# 2016-04-01 00:00:00    Chlorodinine        7  0.943983
# 2016-04-01 00:00:00         AGOC-3A        3  0.722303
# ...                             ...      ...       ...
# 2016-12-31 23:00:00         AGOC-3A        1  0.078266
# 2016-12-31 23:00:00  Methylosmolene        3  0.062784
# 2016-12-31 23:00:00         AGOC-3A        2  0.060814
# 2016-12-31 23:00:00     Appluimonia        7  0.039729
# 2016-12-31 23:00:00         AGOC-3A        7  0.014658
#
# [79243 rows x 3 columns]

# %%
# Unique Values in Monitor

sensor_data["Monitor"].unique()
# Out:
# array([3, 7, 2, 8, 6, 1, 4, 9, 5])

# %% [markdown]
# ## Create Separate Data Frames for each Sensor

# %%
# Create a new data frame for Sensor 1
sensor_1 = sensor_data[sensor_data.Monitor == 1]
sensor_1 = sensor_1.sort_values(by=['Chemical'])

# %%
# Create a new data frame for Sensor 2
sensor_2 = sensor_data[sensor_data.Monitor == 2]
sensor_2 = sensor_2.sort_values(by=['Chemical'])

# %%
# Create a new data frame for Sensor 3
sensor_3 = sensor_data[sensor_data.Monitor == 3]
sensor_3 = sensor_3.sort_values(by=['Chemical'])

# %%
# Create a new data frame for Sensor 4
sensor_4 = sensor_data[sensor_data.Monitor == 4]
sensor_4 = sensor_4.sort_values(by=['Chemical'])

# %%
# Create a new data frame for Sensor 5
sensor_5 = sensor_data[sensor_data.Monitor == 5]
sensor_5 = sensor_5.sort_values(by=['Chemical'])

# %%
# Create a new data frame for Sensor 6
sensor_6 = sensor_data[sensor_data.Monitor == 6]
sensor_6 = sensor_6.sort_values(by=['Chemical'])

# %%
# Create a new data fram for Sensor 7
sensor_7 = sensor_data[sensor_data.Monitor == 7]
sensor_7 = sensor_7.sort_values(by=['Chemical'])

# %%
# Create a new data fram for Sensor 8
sensor_8 = sensor_data[sensor_data.Monitor == 8]
sensor_8 = sensor_8.sort_values(by=['Chemical'])

# %%
# Create a new data fram for Sensor 9
sensor_9 = sensor_data[sensor_data.Monitor == 9]
sensor_9 = sensor_9.sort_values(by=['Chemical'])

# %% [markdown]
# ## Create Separate Data Frames per sensor per month

# %%
# Sensor 1 data frames

sensor_1_2016_04 = sensor_1[sensor_1['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_1_2016_04 = sensor_1_2016_04.sort_values(by=['Chemical'])

sensor_1_2016_08 = sensor_1[sensor_1['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_1_2016_08 = sensor_1_2016_08.sort_values(by=['Chemical'])

sensor_1_2016_12 = sensor_1[sensor_1['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_1_2016_12 = sensor_1_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 2 data frames

sensor_2_2016_04 = sensor_2[sensor_2['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_2_2016_04 = sensor_2_2016_04.sort_values(by=['Chemical'])

sensor_2_2016_08 = sensor_2[sensor_2['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_2_2016_08 = sensor_2_2016_08.sort_values(by=['Chemical'])

sensor_2_2016_12 = sensor_2[sensor_2['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_2_2016_12 = sensor_2_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 3 data frames

sensor_3_2016_04 = sensor_3[sensor_3['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_3_2016_04 = sensor_3_2016_04.sort_values(by=['Chemical'])

sensor_3_2016_08 = sensor_3[sensor_3['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_3_2016_08 = sensor_3_2016_08.sort_values(by=['Chemical'])

sensor_3_2016_12 = sensor_3[sensor_3['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_3_2016_12 = sensor_3_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 4 data frames

sensor_4_2016_04 = sensor_4[sensor_4['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_4_2016_04 = sensor_4_2016_04.sort_values(by=['Chemical'])

sensor_4_2016_08 = sensor_4[sensor_4['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_4_2016_08 = sensor_4_2016_08.sort_values(by=['Chemical'])

sensor_4_2016_12 = sensor_4[sensor_4['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_4_2016_12 = sensor_4_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 5 data frames

sensor_5_2016_04 = sensor_5[sensor_5['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_5_2016_04 = sensor_5_2016_04.sort_values(by=['Chemical'])

sensor_5_2016_08 = sensor_5[sensor_5['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_5_2016_08 = sensor_5_2016_08.sort_values(by=['Chemical'])

sensor_5_2016_12 = sensor_5[sensor_5['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_5_2016_12 = sensor_5_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 6 data frames

sensor_6_2016_04 = sensor_6[sensor_6['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_6_2016_04 = sensor_6_2016_04.sort_values(by=['Chemical'])

sensor_6_2016_08 = sensor_6[sensor_6['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_6_2016_08 = sensor_6_2016_08.sort_values(by=['Chemical'])

sensor_6_2016_12 = sensor_6[sensor_6['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_6_2016_12 = sensor_6_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 7 data frames

sensor_7_2016_04 = sensor_7[sensor_7['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_7_2016_04 = sensor_7_2016_04.sort_values(by=['Chemical'])

sensor_7_2016_08 = sensor_7[sensor_7['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_7_2016_08 = sensor_7_2016_08.sort_values(by=['Chemical'])

sensor_7_2016_12 = sensor_7[sensor_7['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_7_2016_12 = sensor_7_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 8 data frames

sensor_8_2016_04 = sensor_8[sensor_8['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_8_2016_04 = sensor_8_2016_04.sort_values(by=['Chemical'])

sensor_8_2016_08 = sensor_8[sensor_8['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_8_2016_08 = sensor_8_2016_08.sort_values(by=['Chemical'])

sensor_8_2016_12 = sensor_8[sensor_8['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_8_2016_12 = sensor_8_2016_12.sort_values(by=['Chemical'])

# %%
# Sensor 9 data frames

sensor_9_2016_04 = sensor_9[sensor_9['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
sensor_9_2016_04 = sensor_9_2016_04.sort_values(by=['Chemical'])

sensor_9_2016_08 = sensor_9[sensor_9['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
sensor_9_2016_08 = sensor_9_2016_08.sort_values(by=['Chemical'])

sensor_9_2016_12 = sensor_9[sensor_9['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
sensor_9_2016_12 = sensor_9_2016_12.sort_values(by=['Chemical'])

# %% [markdown]
# ## Calculating Significance Cut-Offs

# %%
# Cutoff for Sensor 1

mean_sensor1 = sensor_1['Reading'].mean().round(2)
std_sensor1 = sensor_1['Reading'].std().round(2)
cutoff_sensor1 = mean_sensor1 + (3 * std_sensor1).round(2)

# %%
# Cutoff for Sensor 2

mean_sensor2 = sensor_2['Reading'].mean().round(2)
std_sensor2 = sensor_2['Reading'].std().round(2)
cutoff_sensor2 = mean_sensor2 + (3 * std_sensor2).round(2)

# %%
# Cutoff for Sensor 3

mean_sensor3 = sensor_3['Reading'].mean().round(2)
std_sensor3 = sensor_3['Reading'].std().round(2)
cutoff_sensor3 = mean_sensor3 + (3 * std_sensor3).round(2)

# %%
# Cutoff for Sensor 4

mean_sensor4 = sensor_4['Reading'].mean().round(2)
std_sensor4 = sensor_4['Reading'].std().round(2)
cutoff_sensor4 = mean_sensor4 + (3 * std_sensor4).round(2)

# %%
# Cutoff for Sensor 5

mean_sensor5 = sensor_5['Reading'].mean().round(2)
std_sensor5 = sensor_5['Reading'].std().round(2)
cutoff_sensor5 = mean_sensor5 + (3 * std_sensor5).round(2)

# %%
# Cutoff for Sensor 6

mean_sensor6 = sensor_6['Reading'].mean().round(2)
std_sensor6 = sensor_6['Reading'].std().round(2)
cutoff_sensor6 = mean_sensor6 + (3 * std_sensor6).round(2)

# %%
# Cutoff for Sensor 7

mean_sensor7 = sensor_7['Reading'].mean().round(2)
std_sensor7 = sensor_7['Reading'].std().round(2)
cutoff_sensor7 = mean_sensor7 + (3 * std_sensor7).round(2)

# %%
# Cutoff for Sensor 8

mean_sensor8 = sensor_8['Reading'].mean().round(2)
std_sensor8 = sensor_8['Reading'].std().round(2)
cutoff_sensor8 = mean_sensor8 + (3 * std_sensor8).round(2)

# %%
# Cutoff for Sensor 9

mean_sensor9 = sensor_9['Reading'].mean().round(2)
std_sensor9 = sensor_9['Reading'].std().round(2)
cutoff_sensor9 = mean_sensor9 + (3 * std_sensor9).round(2)

# %%
# Table of Cut-offs

table = [['Sensor', 'Mean Reading', 'Standard Deviation', 'Cut-Off'],  
         ['Sensor 1', mean_sensor1, std_sensor1, cutoff_sensor1], 
         ['Sensor 2', mean_sensor2, std_sensor2, cutoff_sensor2], 
         ['Sensor 3', mean_sensor3, std_sensor3, cutoff_sensor3], 
         ['Sensor 4', mean_sensor4, std_sensor4, cutoff_sensor4], 
         ['Sensor 5', mean_sensor5, std_sensor5, cutoff_sensor5], 
         ['Sensor 6', mean_sensor6, std_sensor6, cutoff_sensor6], 
         ['Sensor 7', mean_sensor7, std_sensor7, cutoff_sensor7], 
         ['Sensor 8', mean_sensor8, std_sensor8, cutoff_sensor8], 
         ['Sensor 9', mean_sensor9, std_sensor9, cutoff_sensor9]]

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤════════════════╤══════════════════════╤═══════════╕
# │ Sensor   │   Mean Reading │   Standard Deviation │   Cut-Off │
# ╞══════════╪════════════════╪══════════════════════╪═══════════╡
# │ Sensor 1 │           0.25 │                 0.52 │      1.81 │
# ├──────────┼────────────────┼──────────────────────┼───────────┤
# │ Sensor 2 │           0.39 │                 1.07 │      3.6  │
# ├──────────┼────────────────┼──────────────────────┼───────────┤
# │ Sensor 3 │           1.42 │                 2.6  │      9.22 │
# ├──────────┼────────────────┼──────────────────────┼───────────┤
# │ Sensor 4 │           1.28 │                 1.89 │      6.95 │
# ├──────────┼────────────────┼──────────────────────┼───────────┤
# │ Sensor 5 │           0.61 │                 2.01 │      6.64 │
# ├──────────┼────────────────┼──────────────────────┼───────────┤
# │ Sensor 6 │           0.84 │                 4.17 │     13.35 │
# ...

# %% [markdown]
# ## Visualization of Chemicals per sensor per month

# %% [markdown]
# ### Sensor 1

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_1_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 1 Data (04-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor1, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_1_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 1 Data (08-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor1, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_1_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 1 Data (12-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor1, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 2

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_2_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 2 Data (04-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor2, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_2_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 2 Data (08-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor2, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_2_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 2 Data (12-2016)")
# plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor2, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 3

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_3_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 3 Data (04-2016)")
plt.ylim([0, 20])
plt.axhline(y = cutoff_sensor3, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_3_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 3 Data (08-2016)")
plt.ylim([0, 20])
plt.axhline(y = cutoff_sensor3, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_3_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 3 Data (12-2016)")
plt.ylim([0, 20])
plt.axhline(y = cutoff_sensor3, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 4

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_4_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 4 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor4, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_4_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 4 Data (08-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor4, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_4_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 4 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor4, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 5

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_5_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 5 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor5, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_5_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 5 Data (08-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor5, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_5_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 5 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor5, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 6

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_6_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 6 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor6, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_6_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 6 Data (08-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor6, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_6_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 6 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor6, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 7

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_7_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 7 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor7, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_7_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 7 Data (08-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor7, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_7_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 7 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor7, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 8

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_8_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 8 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor8, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_8_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 8 Data (08-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor8, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_8_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 8 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor8, color ="black", linestyle ="--")

# %% [markdown]
# ### Sensor 9

# %%
# April

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_9_2016_04, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 9 Data (04-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor9, color ="black", linestyle ="--")

# %%
# August

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_9_2016_08, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 9 Data (08-2016)")
plt.ylim([0, 15])
plt.axhline(y = cutoff_sensor9, color ="black", linestyle ="--")

# %%
# December

fig, ax = plt.subplots(figsize=(10,6))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.xticks(rotation = 90)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
sns.lineplot(data = sensor_9_2016_12, x = 'Date_Time', y = 'Reading', hue = 'Chemical').set(title = "Sensor 9 Data (12-2016)")
plt.ylim([0, 100])
plt.axhline(y = cutoff_sensor9, color ="black", linestyle ="--")

# %% [markdown]
# ## Which Chemicals are being detected significantly at each sensor?

# %%
sensor_1_sig = sensor_1[sensor_1['Reading'] >= cutoff_sensor1]
sensor1_counts = dict(sensor_1_sig['Chemical'].value_counts())
sensor1_counts_sum = sensor_1_sig['Chemical'].value_counts().sum()

# %%
sensor_2_sig = sensor_2[sensor_2['Reading'] >= cutoff_sensor2]
sensor2_counts = dict(sensor_2_sig['Chemical'].value_counts())
sensor2_counts_sum = sensor_2_sig['Chemical'].value_counts().sum()

# %%
sensor_3_sig = sensor_3[sensor_3['Reading'] >= cutoff_sensor3]
sensor3_counts = dict(sensor_3_sig['Chemical'].value_counts())
sensor3_counts_sum = sensor_3_sig['Chemical'].value_counts().sum()

# %%
sensor_4_sig = sensor_4[sensor_4['Reading'] >= cutoff_sensor4]
sensor4_counts = dict(sensor_4_sig['Chemical'].value_counts())
sensor4_counts_sum = sensor_4_sig['Chemical'].value_counts().sum()

# %%
sensor_5_sig = sensor_5[sensor_5['Reading'] >= cutoff_sensor5]
sensor5_counts = dict(sensor_5_sig['Chemical'].value_counts())
sensor5_counts_sum = sensor_5_sig['Chemical'].value_counts().sum()

# %%
sensor_6_sig = sensor_6[sensor_6['Reading'] >= cutoff_sensor6]
sensor6_counts = dict(sensor_6_sig['Chemical'].value_counts())
sensor6_counts_sum = sensor_6_sig['Chemical'].value_counts().sum()

# %%
sensor_7_sig = sensor_7[sensor_7['Reading'] >= cutoff_sensor7]
sensor7_counts = dict(sensor_7_sig['Chemical'].value_counts())
sensor7_counts_sum = sensor_7_sig['Chemical'].value_counts().sum()

# %%
sensor_8_sig = sensor_8[sensor_8['Reading'] >= cutoff_sensor8]
sensor8_counts = dict(sensor_8_sig['Chemical'].value_counts())
sensor8_counts_sum = sensor_8_sig['Chemical'].value_counts().sum()

# %%
sensor_9_sig = sensor_9[sensor_9['Reading'] >= cutoff_sensor9]
sensor9_counts = dict(sensor_9_sig['Chemical'].value_counts())
sensor9_counts_sum = sensor_9_sig['Chemical'].value_counts().sum()

# %%
table2 = [['Sensor', 'Chemical:Counts', 'Sum of counts'], 
          ['Sensor 1', sensor1_counts, sensor1_counts_sum],
          ['Sensor 2', sensor2_counts, sensor2_counts_sum], 
          ['Sensor 3', sensor3_counts, sensor3_counts_sum],
          ['Sensor 4', sensor4_counts, sensor4_counts_sum], 
          ['Sensor 5', sensor5_counts, sensor5_counts_sum], 
          ['Sensor 6', sensor6_counts, sensor6_counts_sum], 
          ['Sensor 7', sensor7_counts, sensor7_counts_sum], 
          ['Sensor 8', sensor8_counts, sensor8_counts_sum], 
          ['Sensor 9', sensor9_counts, sensor9_counts_sum]]
print(tabulate(table2, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤════════════════════════════════════════════════════════════════════════════╤═════════════════╕
# │ Sensor   │ Chemical:Counts                                                            │   Sum of counts │
# ╞══════════╪════════════════════════════════════════════════════════════════════════════╪═════════════════╡
# │ Sensor 1 │ {'Chlorodinine': 5, 'AGOC-3A': 4, 'Appluimonia': 3, 'Methylosmolene': 1}   │              13 │
# ├──────────┼────────────────────────────────────────────────────────────────────────────┼─────────────────┤
# │ Sensor 2 │ {'AGOC-3A': 7, 'Methylosmolene': 3, 'Chlorodinine': 2}                     │              12 │
# ├──────────┼────────────────────────────────────────────────────────────────────────────┼─────────────────┤
# │ Sensor 3 │ {'AGOC-3A': 23, 'Methylosmolene': 16}                                      │              39 │
# ├──────────┼────────────────────────────────────────────────────────────────────────────┼─────────────────┤
# ...

# %%
# Export Tabulation

export_tabulation = tabulate(table2, headers='firstrow', tablefmt='fancy_grid')
text_file=open("sensor_counts_chemical.csv","w")
text_file.write(export_tabulation)
text_file.close()

# %% [markdown]
# ## What patterns of chemical releases do you see, as being reported in the data?

# %%
sig_all = pd.concat([sensor_1_sig, sensor_2_sig, sensor_3_sig, sensor_4_sig, sensor_5_sig, sensor_6_sig, 
                     sensor_7_sig, sensor_8_sig, sensor_9_sig])

sig_all.set_index('Date_Time')
# Out:
#                            Chemical  Monitor   Reading
# Date_Time
# 2016-08-02 14:00:00         AGOC-3A        1  10.73531
# 2016-12-05 06:00:00         AGOC-3A        1   3.68059
# 2016-12-05 06:00:00         AGOC-3A        1  31.66583
# 2016-12-07 01:00:00         AGOC-3A        1   3.16696
# 2016-08-20 04:00:00     Appluimonia        1   2.20189
# ...                             ...      ...       ...
# 2016-12-08 00:00:00  Methylosmolene        9  21.44570
# 2016-04-11 03:00:00  Methylosmolene        9  42.51119
# 2016-12-19 23:00:00  Methylosmolene        9  16.12934
# 2016-12-14 23:00:00  Methylosmolene        9  12.84821
# 2016-12-16 22:00:00  Methylosmolene        9   7.71616
#
# [356 rows x 3 columns]

# %%
april_data = sensor_data[sensor_data['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
april_data = april_data.sort_values(by=['Chemical'])

april = sns.relplot(data = april_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
april.set_xticklabels(rotation=45)

# %%
april_sig_data = sig_all[sig_all['Date_Time'].dt.strftime('%Y-%m') == '2016-04']
april_sig_data = april_sig_data.sort_values(by=['Chemical'])

april_sig = sns.relplot(data = april_sig_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
april_sig.set_xticklabels(rotation=45)

# %%
aug_data = sensor_data[sensor_data['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
aug_data = aug_data.sort_values(by=['Chemical'])

aug = sns.relplot(data = aug_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
aug.set_xticklabels(rotation=45)

# %%
aug_sig_data = sig_all[sig_all['Date_Time'].dt.strftime('%Y-%m') == '2016-08']
aug_sig_data = aug_sig_data.sort_values(by=['Chemical'])

aug_sig = sns.relplot(data = aug_sig_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
aug_sig.set_xticklabels(rotation=45)

# %%
dec_data = sensor_data[sensor_data['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
dec_data = dec_data.sort_values(by=['Chemical'])

dec = sns.relplot(data = dec_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
dec.set_xticklabels(rotation=45)

# %%
dec_sig_data = sig_all[sig_all['Date_Time'].dt.strftime('%Y-%m') == '2016-12']
dec_sig_data = dec_sig_data.sort_values(by=['Chemical'])

dec_sig = sns.relplot(data = dec_sig_data, x = 'Date_Time', y = 'Reading', col = 'Chemical')
dec_sig.set_xticklabels(rotation=45)

# %%
sig_all_copy = sig_all
sig_all_copy['Month'] = pd.DatetimeIndex(sig_all_copy['Date_Time']).month
# sig_all_copy

# %%
sig_all = sns.relplot(data = sig_all_copy, x = 'Monitor', y = 'Reading', hue = 'Month', col = 'Chemical', 
                      palette=["b", "r", "g"])

# %%
sig_all2 = sns.relplot(data = sig_all_copy, x = 'Monitor', y = 'Reading', hue = 'Chemical', col = 'Month', col_wrap= 3)

# %%
# Rolling Average

sensor_data['Month'] = pd.DatetimeIndex(sensor_data['Date_Time']).month
sensor_data['Rolling(30)'] = sensor_data['Reading'].rolling(30).mean()
sensor_data
# Out:
#              Chemical  Monitor           Date_Time   Reading  Month  \
# 0      Methylosmolene        3 2016-04-01 00:00:00  2.683820      4
# 1      Methylosmolene        7 2016-04-01 00:00:00  2.630640      4
# 2        Chlorodinine        3 2016-04-01 00:00:00  1.259170      4
# 3        Chlorodinine        7 2016-04-01 00:00:00  0.943983      4
# 4             AGOC-3A        3 2016-04-01 00:00:00  0.722303      4
# ...               ...      ...                 ...       ...    ...
# 79238         AGOC-3A        1 2016-12-31 23:00:00  0.078266     12
# 79239  Methylosmolene        3 2016-12-31 23:00:00  0.062784     12
# 79240         AGOC-3A        2 2016-12-31 23:00:00  0.060814     12
# 79241     Appluimonia        7 2016-12-31 23:00:00  0.039729     12
# 79242         AGOC-3A        7 2016-12-31 23:00:00  0.014658     12
#
#        Rolling(30)
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# ...

# %%
rolling_agoc_april = sensor_data[(sensor_data.Chemical == 'AGOC-3A') & (sensor_data.Month == 4)]

sns.lineplot(x = 'Date_Time', y = 'Reading', data = rolling_agoc_april, label = 'Reading')
sns.lineplot(x = 'Date_Time', y = 'Rolling(30)', data = rolling_agoc_april, label = 'Rolling Avg')
plt.xticks(rotation=45)
plt.title('AGOC-3A Rolling Averages April')
# Out:
# Text(0.5, 1.0, 'AGOC-3A Rolling Averages April')

# %%
rolling_agoc_aug = sensor_data[(sensor_data.Chemical == 'AGOC-3A') & (sensor_data.Month == 8)]

sns.lineplot(x = 'Date_Time', y = 'Reading', data = rolling_agoc_aug, label = 'Reading')
sns.lineplot(x = 'Date_Time', y = 'Rolling(30)', data = rolling_agoc_aug, label = 'Rolling Avg')
plt.xticks(rotation=45)
plt.title('AGOC-3A Rolling Averages August')
plt.show()

# %%
rolling_agoc_dec = sensor_data[(sensor_data.Chemical == 'AGOC-3A') & (sensor_data.Month == 12)]

sns.lineplot(x = 'Date_Time', y = 'Reading', data = rolling_agoc_dec, label = 'Reading')
sns.lineplot(x = 'Date_Time', y = 'Rolling(30)', data = rolling_agoc_dec, label = 'Rolling Avg')
plt.xticks(rotation=45)
plt.title('AGOC-3A Rolling Averages December')
plt.show()
