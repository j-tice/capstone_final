# %%
import datetime
datetime.datetime.strptime
import math
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# %%
headers = ['Name', 'x', 'y']
table3 = [['Kasios Office Furniture', 90, 21], ['Radiance ColourTek', 109, 26], ['Indigo Sol Boards', 120, 22], 
          ['Roadrunner Fitness Electronics', 89, 27], ['Sensor 1', 62, 21], ['Sensor 2', 66, 35], ['Sensor 3', 76, 41], 
          ['Sensor 4', 88, 45], ['Sensor 5', 103, 43], ['Sensor 6', 102, 22], ['Sensor 7', 89, 3], ['Sensor 8', 74, 7], 
          ['Sensor 9', 119, 42]]

new_df = pd.DataFrame(table3)
new_df.columns = headers
new_df
# Out:
#                               Name    x   y
# 0          Kasios Office Furniture   90  21
# 1               Radiance ColourTek  109  26
# 2                Indigo Sol Boards  120  22
# 3   Roadrunner Fitness Electronics   89  27
# 4                         Sensor 1   62  21
# 5                         Sensor 2   66  35
# 6                         Sensor 3   76  41
# 7                         Sensor 4   88  45
# 8                         Sensor 5  103  43
# 9                         Sensor 6  102  22
# 10                        Sensor 7   89   3
# 11                        Sensor 8   74   7
# 12                        Sensor 9  119  42

# %%
# Calculate Distance between sensors/factories

kasios_sensor1 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[4][1], new_df.loc[4][2]])
kasios_sensor2 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[5][1], new_df.loc[5][2]])
kasios_sensor3 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[6][1], new_df.loc[6][2]])
kasios_sensor4 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[7][1], new_df.loc[7][2]])
kasios_sensor5 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[8][1], new_df.loc[8][2]])
kasios_sensor6 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[9][1], new_df.loc[9][2]])
kasios_sensor7 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[10][1], new_df.loc[10][2]])
kasios_sensor8 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[11][1], new_df.loc[11][2]])
kasios_sensor9 = math.dist([new_df.loc[0][1], new_df.loc[0][2]], [new_df.loc[12][1], new_df.loc[12][2]])

radiance_sensor1 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[4][1], new_df.loc[4][2]])
radiance_sensor2 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[5][1], new_df.loc[5][2]])
radiance_sensor3 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[6][1], new_df.loc[6][2]])
radiance_sensor4 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[7][1], new_df.loc[7][2]])
radiance_sensor5 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[8][1], new_df.loc[8][2]])
radiance_sensor6 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[9][1], new_df.loc[9][2]])
radiance_sensor7 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[10][1], new_df.loc[10][2]])
radiance_sensor8 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[11][1], new_df.loc[11][2]])
radiance_sensor9 = math.dist([new_df.loc[1][1], new_df.loc[1][2]], [new_df.loc[12][1], new_df.loc[12][2]])

indigo_sensor1 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[4][1], new_df.loc[4][2]])
indigo_sensor2 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[5][1], new_df.loc[5][2]])
indigo_sensor3 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[6][1], new_df.loc[6][2]])
indigo_sensor4 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[7][1], new_df.loc[7][2]])
indigo_sensor5 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[8][1], new_df.loc[8][2]])
indigo_sensor6 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[9][1], new_df.loc[9][2]])
indigo_sensor7 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[10][1], new_df.loc[10][2]])
indigo_sensor8 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[11][1], new_df.loc[11][2]])
indigo_sensor9 = math.dist([new_df.loc[2][1], new_df.loc[2][2]], [new_df.loc[12][1], new_df.loc[12][2]])

roadrunner_sensor1 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[4][1], new_df.loc[4][2]])
roadrunner_sensor2 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[5][1], new_df.loc[5][2]])
roadrunner_sensor3 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[6][1], new_df.loc[6][2]])
roadrunner_sensor4 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[7][1], new_df.loc[7][2]])
roadrunner_sensor5 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[8][1], new_df.loc[8][2]])
roadrunner_sensor6 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[9][1], new_df.loc[9][2]])
roadrunner_sensor7 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[10][1], new_df.loc[10][2]])
roadrunner_sensor8 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[11][1], new_df.loc[11][2]])
roadrunner_sensor9 = math.dist([new_df.loc[3][1], new_df.loc[3][2]], [new_df.loc[12][1], new_df.loc[12][2]])

# %%
# Create a table of distances calculated above

dist_table = [['Factory', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8','S9'],
             ['Kasios', kasios_sensor1, kasios_sensor2, kasios_sensor3, kasios_sensor4, kasios_sensor5, 
              kasios_sensor6, kasios_sensor7, kasios_sensor8, kasios_sensor9],
             ['Radiance', radiance_sensor1, radiance_sensor2, radiance_sensor3, radiance_sensor4, radiance_sensor5, 
              radiance_sensor6, radiance_sensor7, radiance_sensor8, radiance_sensor9],
             ['Indigo', indigo_sensor1, indigo_sensor2, indigo_sensor3, indigo_sensor4, indigo_sensor5, indigo_sensor6, 
             indigo_sensor7, indigo_sensor8, indigo_sensor9],
             ['Roadrunner', roadrunner_sensor1, roadrunner_sensor2, roadrunner_sensor3, roadrunner_sensor4, roadrunner_sensor5, 
             roadrunner_sensor6, roadrunner_sensor7, roadrunner_sensor8, roadrunner_sensor9]]

print(tabulate(dist_table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒════════════╤═════════╤═════════╤═════════╤═════════╤═════════╤══════════╤═════════╤═════════╤════════╕
# │ Factory    │      S1 │      S2 │      S3 │      S4 │      S5 │       S6 │      S7 │      S8 │     S9 │
# ╞════════════╪═════════╪═════════╪═════════╪═════════╪═════════╪══════════╪═════════╪═════════╪════════╡
# │ Kasios     │ 28      │ 27.7849 │ 24.4131 │ 24.0832 │ 25.5539 │ 12.0416  │ 18.0278 │ 21.2603 │ 35.805 │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┼─────────┼─────────┼────────┤
# │ Radiance   │ 47.2652 │ 43.9318 │ 36.2491 │ 28.3196 │ 18.0278 │  8.06226 │ 30.4795 │ 39.8246 │ 18.868 │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┼─────────┼─────────┼────────┤
# │ Indigo     │ 58.0086 │ 55.5428 │ 47.927  │ 39.4081 │ 27.0185 │ 18       │ 36.3593 │ 48.3839 │ 20.025 │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┼─────────┼─────────┼────────┤
# ...

# %%
# Create a scatterplot to visualize the factories in relation to the sensors

plt.figure(figsize=(8,5))
sns.scatterplot(data=new_df,x='x',y='y')
plt.title('Locations') #title
plt.xlabel('x') #x label
plt.ylabel('y') #y label

plt.text(new_df.x[new_df.Name =='Kasios Office Furniture']- 2.5, new_df.y[new_df.Name == 'Kasios Office Furniture'] - 2.5,
         "Kasios", color='black')
plt.text(new_df.x[new_df.Name == 'Radiance ColourTek']+ 1,new_df.y[new_df.Name == 'Radiance ColourTek']+ 1,
         "Radiance", color='black')
plt.text(new_df.x[new_df.Name == 'Indigo Sol Boards'] - 2.5,new_df.y[new_df.Name == 'Indigo Sol Boards'] - 2.5,
         "Indigo", color='black')
plt.text(new_df.x[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,new_df.y[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,
         "Roadrunner", color='black')
plt.text(new_df.x[new_df.Name == 'Sensor 1']- 2.5, new_df.y[new_df.Name == 'Sensor 1']- 2.5, "Sensor 1", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 2']- 2.5, new_df.y[new_df.Name == 'Sensor 2']- 2.5, "Sensor 2", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 3']- 2.5, new_df.y[new_df.Name == 'Sensor 3']- 2.5, "Sensor 3", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 4']- 2.5, new_df.y[new_df.Name == 'Sensor 4']- 2.5, "Sensor 4", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 5']- 2.5, new_df.y[new_df.Name == 'Sensor 5']- 2.5, "Sensor 5", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 6']- 2.5, new_df.y[new_df.Name == 'Sensor 6']- 2.5, "Sensor 6", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 7']- 2.5, new_df.y[new_df.Name == 'Sensor 7']- 2.5, "Sensor 7", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 8']- 2.5, new_df.y[new_df.Name == 'Sensor 8']- 2.5, "Sensor 8", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 9']- 2.5, new_df.y[new_df.Name == 'Sensor 9']- 2.5, "Sensor 9", color='red')


plt.xlim(new_df.x.min()-5,new_df.x.max()+5)
plt.ylim(new_df.y.min()-5,new_df.y.max()+5)
plt.show()

# %%
# Add closest relations

plt.figure(figsize=(8,5))
sns.scatterplot(data=new_df,x='x',y='y')
plt.title('Closest Relationships between Factories and Sensors') #title
plt.xlabel('x') #x label
plt.ylabel('y') #y label

plt.plot([new_df.loc[0][1],new_df.loc[4][1]], [new_df.loc[0][2], new_df.loc[4][2]], 'k', linestyle="--")
plt.plot([new_df.loc[3][1],new_df.loc[5][1]], [new_df.loc[3][2], new_df.loc[5][2]], 'k', linestyle="--")
plt.plot([new_df.loc[3][1],new_df.loc[6][1]], [new_df.loc[3][2], new_df.loc[6][2]], 'k', linestyle="--")
plt.plot([new_df.loc[3][1],new_df.loc[7][1]], [new_df.loc[3][2], new_df.loc[7][2]], 'k', linestyle="--")
plt.plot([new_df.loc[1][1],new_df.loc[8][1]], [new_df.loc[1][2], new_df.loc[8][2]], 'k', linestyle="--")
plt.plot([new_df.loc[1][1],new_df.loc[9][1]], [new_df.loc[1][2], new_df.loc[9][2]], 'k', linestyle="--")
plt.plot([new_df.loc[0][1],new_df.loc[10][1]], [new_df.loc[0][2], new_df.loc[10][2]], 'k', linestyle="--")
plt.plot([new_df.loc[0][1],new_df.loc[11][1]], [new_df.loc[0][2], new_df.loc[11][2]], 'k', linestyle="--")
plt.plot([new_df.loc[1][1],new_df.loc[12][1]], [new_df.loc[1][2], new_df.loc[12][2]], 'k', linestyle="--")

plt.text(new_df.x[new_df.Name =='Kasios Office Furniture']+ 1, new_df.y[new_df.Name == 'Kasios Office Furniture'] + 1,
         "Kasios", color='black')
plt.text(new_df.x[new_df.Name == 'Radiance ColourTek'] + 1,new_df.y[new_df.Name == 'Radiance ColourTek'] - 2,
         "Radiance", color='black')
plt.text(new_df.x[new_df.Name == 'Indigo Sol Boards'] - 2.5,new_df.y[new_df.Name == 'Indigo Sol Boards'] - 3,
         "Indigo", color='black')
plt.text(new_df.x[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,new_df.y[new_df.Name == 'Roadrunner Fitness Electronics'] + 1,
         "Roadrunner", color='black')
plt.text(new_df.x[new_df.Name == 'Sensor 1']- 2.5, new_df.y[new_df.Name == 'Sensor 1']- 2.5, "Sensor 1", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 2']+ 1, new_df.y[new_df.Name == 'Sensor 2']+ 1, "Sensor 2", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 3']+ 1, new_df.y[new_df.Name == 'Sensor 3']+ 1, "Sensor 3", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 4']+ 1, new_df.y[new_df.Name == 'Sensor 4']+ 1, "Sensor 4", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 5']+ 1, new_df.y[new_df.Name == 'Sensor 5']+ 1, "Sensor 5", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 6']- 2.5, new_df.y[new_df.Name == 'Sensor 6']- 2.5, "Sensor 6", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 7']- 2.5, new_df.y[new_df.Name == 'Sensor 7']- 2.5, "Sensor 7", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 8']- 2.5, new_df.y[new_df.Name == 'Sensor 8']- 2.5, "Sensor 8", color='red')
plt.text(new_df.x[new_df.Name == 'Sensor 9'] + 1, new_df.y[new_df.Name == 'Sensor 9'] + 1, "Sensor 9", color='red')


plt.xlim(new_df.x.min()-5,new_df.x.max()+ 10)
plt.ylim(new_df.y.min()-5,new_df.y.max()+ 10)
plt.show()
